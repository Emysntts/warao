# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Lendo os dados

# %%
import pandas as pd

# %%
dataset_frases = pd.read_csv('data/dicionário_frases.csv')

dataset_palavras = pd.read_csv('data/dicionario_palavras.csv')

# %%
dataset_frases
# Out:
#                   Português               Espanhol                Warao  \
# 0                Todo mundo          Todo el mundo        Ina kokotuka.
# 1                As pessoas           Las personas           Waraotuma.
# 2                 O pessoal            El personal        Tai Waraotuma
# 3                 Estou bem             Estoy bien          Ine Yakera.
# 4                Meu nome é           Mi nombre es            Ine Mawai
# ..                      ...                    ...                  ...
# 84                   Me dói            Me duele(n)                Ajera
# 85         Eu sou diabético          Soy diabético   Jotu isia nobaraya
# 86  Eu tenho a pressão alta  Sufro de presión alta  Kobe isiya nobaraya
# 87            Estou gripado        Estoy con gripe       Obo maisiya ja
# 88             Eu tenho dor            Tengo dolor           Tejo Ajera
#
#     Unnamed: 3                                 Contexto/categoria
# ...

# %%
dataset_palavras
# Out:
#                                              Português  \
# 0                                                   Eu
# 1                                                   Tu
# 2                                                  Ele
# 3                                                Vocês
# 4                                                  Ela
# ..                                                 ...
# 423                             Certidão de Nascimento
# 424                             Carteira de identidade
# 425                               Carteira de trabalho
# 426  Carteira de motorista\nCarnet / Registro / Lic...
# 427                              Ferro de passar roupa
#
#                          Espanhol              Warao  Unnamed: 3  \
# 0                              Yo                Ine         NaN
# 1                              Tú                Iji         NaN
# 2                              Él                Tai         NaN
# ...
